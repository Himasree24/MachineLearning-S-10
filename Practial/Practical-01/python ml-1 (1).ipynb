# %%
x =5
y = 3.14
name = "CGPA"
is_placed = True

print(x, type(x))
print(y, type(y))
print(name, type(name))
print(is_placed, type(is_placed))
# Out:
# 5 <class 'int'>
# 3.14 <class 'float'>
# CGPA <class 'str'>
# True <class 'bool'>

# %%
a = 7
b = 2
print("a + b" , a+b)
print("a - b" , a-b)
print("a * b" , a*b)
print("a / b" , a/b)
print("a ** b" , a**b)

cgpa = 8.4
print("cgpa == 8.4:", cgpa == 8.4)
print("cgpa > 8 :", cgpa > 8)
print("cgpa < 6 :", cgpa < 6)

attendence = 85
placed = (cgpa > 8) and (attendence > 80)
print("placed :", placed)
placed = (cgpa > 8) or (attendence > 80)
print("placed :", placed)
placed = not (cgpa > 8)
print("placed :", placed)
# Out:
# a + b 9
# a - b 5
# a * b 14
# a / b 3.5
# a ** b 49
# cgpa == 8.4: True
# cgpa > 8 : True
# cgpa < 6 : False
# placed : True
# placed : True
# placed : False

# %%
model_name = "Logical Regression"
accuracy = 0.87345

print("Accuracy of"  + model_name + "is"+ str(accuracy))
print(f"Accuracy of {model_name} is {accuracy}")
print(f"Accuracy of {model_name} is {accuracy:.3f}")
# Out:
# Accuracy ofLogical Regressionis0.87345
# Accuracy of Logical Regression is 0.87345
# Accuracy of Logical Regression is 0.873
